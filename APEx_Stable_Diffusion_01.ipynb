# %% [markdown]
# <a href="https://colab.research.google.com/github/Agunivers7/3/blob/master/APEx_Stable_Diffusion_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **StableDiffusion GoogleColab version**
#
# # ![pp.png](data:image/png;base64,...) **[Buy me a coffee](https://www.paypal.me/maratsk)**
#
#
# youtube.png **[YouTube](https://www.youtube.com/watch?v=dQw4w9WgXcQ)** | ![youtube.png](data:image/png;base64,...) **[sdg.marat@gmail.com]** |
#
#
# _You don't need additional Google Drive storage because uploaded models are not stored on your Google Drive. After the session ends, all data will be deleted. You can either download ControlNet models on your own or let me know if you want me to make it for you._

# %%
#@markdown # **STEP 1**
#@markdown ## Requirements
from IPython.display import clear_output

print('[1;32mInstalling requirements...')
#%pip install --quiet blendmodes accelerate basicsr fonts font-roboto gfpgan gradio invisible-watermark numpy omegaconf opencv-contrib-python requests piexif Pillow pytorch-lightning==1.7.7 realesrgan scikit-image==0.19 timm==0.4.12 transformers==4.25.1 torch einops jsonmerge clean-fid resize-right torchdiffeq kornia lark inflection GitPython torchsde safetensors psutil rich
#%cd /content/
# !git clone -q --branch main https://github.com/AlexSgt/lite_colab
# %cd /content/lite_colab
# %pip install -r requirements.txt --quiet
# !sed -i "s@os.path.splitext(checkpoint_file)@os.path.splitext(checkpoint_file); map_location='cuda'@" /content/lite_colab/modules/sd_models.py
# !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/lite_colab/startfk.py
# !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/lite_colab/modules/extras.py
# !cp /content/lite_colab/assets/blocks.py /usr/local/lib/python3.10/dist-packages/gradio/blocks.py

clear_output()
print('[1;32mDone!')
#!python launch.py --share --theme dark --api --ckpt-dir /content/models/ --disable-safe-unpickle --enable-insecure-extension-access --opt-sdp-attention --disable-console-progressbars --no-download-sd-model

# %% [markdown]
# <form action="https://www.paypal.com/cgi-bin/webscr" method="post" target="_top">
#   <input type="hidden" name="cmd" value="_s-xclick" />
#   <input type="hidden" name="hosted_button_id" value="MDH8APKUVYW4L" />
#   <table>
#     <tr>
#       <td>
#         <input type="hidden" name="on0" value="Thank you for donation!:)"/>
#         Thank you for donation!:)
#       </td>
#     </tr>
#     <tr>
#       <td>
#         <input type="text" name="os0" maxLength="200" />
#       </td>
#     </tr>
#   </table>
#   <input type="hidden" name="currency_code" value="USD" />
#   <input type="image" src="https://www.paypalobjects.com/en_US/i/btn/btn_paynowCC_LG.gif" border="0" name="submit" title="PayPal - The safer, easier way to pay online!" alt="Buy Now" />
# </form>

# %%
#@markdown # **STEP 2**
#@markdown ## Choose your model
#@markdown _Paste link from huggingface.co or leave the default model_

MODEL_LINK = "https://huggingface.co/SG161222/Realistic_Vision_V2.0/resolve/main/Realistic_Vision_V2.0-fp16-no-ema-inpainting.safetensors" #@param {type:"string"}
safetensors = True #@param {type:"boolean"}

if MODEL_LINK != "":
  pth = '/content/lite_colab/models/Stable-diffusion/'
  if not safetensors:
    modelname="model.ckpt"
  else:
    modelname="model.safetensors"
  dwnld = pth + modelname
  print('[1;32mDownload model...')
  # !gdown --fuzzy -O $dwnld "$MODEL_LINK"
  clear_output()
  print('[1;32mDone!')
else:
  print('[1;31mPaste model link and try again!')

# %%
#@markdown # **STEP 3**
#@markdown ## Start StableDiffusion

# !python launch.py --share --api --disable-safe-unpickle --enable-insecure-extension-access --opt-sdp-attention --disable-console-progressbars --no-download-sd-model
# Out:
# Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# Commit hash: 97a7e49258138c95b5d607e5e0152d52979d760d
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into /content/lite_colab/repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into /content/lite_colab/repositories/taming-transformers...
# Cloning K-diffusion into /content/lite_colab/repositories/k-diffusion...
# Cloning CodeFormer into /content/lite_colab/repositories/CodeFormer...
# Cloning BLIP into /content/lite_colab/repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements
# Installing controlnet requirement: mediapipe
# Installing controlnet requirement: svglib
# Installing controlnet requirement: fvcore
#
# Launching startfk with arguments: --share --api --disable-safe-unpickle --enable-insecure-extension-access --opt-sdp-attention --disable-console-progressbars --no-download-sd-model
# 2023-08-11 12:15:26.951974: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-11 12:15:28.412490: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# No module 'xformers'. Proceeding without it.
# ControlNet v1.1.145
# ControlNet v1.1.145
# Calculating sha256 for /content/lite_colab/models/Stable-diffusion/model.safetensors: 6482f11700cbadc269e0804689e72acb37ad5054c50603835098e575d0786cf4
# Loading weights [6482f11700] from /content/lite_colab/models/Stable-diffusion/model.safetensors
# Creating model from config: /content/lite_colab/configs/v1-inpainting-inference.yaml
# LatentInpaintDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.54 M params.
# Downloading (…)olve/main/vocab.json: 100% 961k/961k [00:00<00:00, 17.7MB/s]
# Downloading (…)olve/main/merges.txt: 100% 525k/525k [00:00<00:00, 41.6MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 2.24MB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 6.02MB/s]
# Downloading (…)lve/main/config.json: 100% 4.52k/4.52k [00:00<00:00, 18.5MB/s]
# Applying scaled dot product cross attention optimization.
# Textual inversion embeddings loaded(0):
# Model loaded in 15.0s (calculate hash: 6.1s, load weights from disk: 1.1s, create model: 1.9s, apply weights to model: 3.7s, apply half(): 1.4s, move model to device: 0.7s).
# Running on public URL: https://0c3dc8cbbd23207e09.gradio.live
# ✔ Connected
# Startup time: 31.8s (import torch: 7.0s, import gradio: 1.5s, import ldm: 0.7s, other imports: 2.0s, setup codeformer: 0.1s, load scripts: 1.2s, load SD checkpoint: 15.0s, create ui: 1.0s, gradio launch: 3.3s).
# 100% 16/16 [00:13<00:00,  1.16it/s]
# Collecting insightface>=0.7.3
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 6.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (1.23.5)
# Collecting onnx (from insightface>=0.7.3)
#   Downloading onnx-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (2.25.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (3.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (0.19.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (1.10)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (0.29.36)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (1.2.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from insightface>=0.7.3) (0.7.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations->insightface>=0.7.3) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations->insightface>=0.7.3) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations->insightface>=0.7.3) (4.8.0.74)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface>=0.7.3) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface>=0.7.3) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface>=0.7.3) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface>=0.7.3) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface>=0.7.3) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface>=0.7.3) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface>=0.7.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface>=0.7.3) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface>=0.7.3) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface>=0.7.3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface>=0.7.3) (2.8.2)
# Collecting protobuf>=3.20.2 (from onnx->insightface>=0.7.3)
#   Downloading protobuf-4.24.0-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx->insightface>=0.7.3) (4.7.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from requests->insightface>=0.7.3) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->insightface>=0.7.3) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->insightface>=0.7.3) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->insightface>=0.7.3) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->insightface>=0.7.3) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->insightface>=0.7.3) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->insightface>=0.7.3) (1.16.0)
# Building wheels for collected packages: insightface
#   Building wheel for insightface (pyproject.toml): started
#   Building wheel for insightface (pyproject.toml): finished with status 'done'
#   Created wheel for insightface: filename=insightface-0.7.3-cp310-cp310-linux_x86_64.whl size=1049446 sha256=1861dec7c8ea1a52ec0bf8ecdd3cf8ef4056b047b29e8c83a3a2f820498a76e5
#   Stored in directory: /root/.cache/pip/wheels/e3/d0/80/e3773fb8b6d1cca87ea1d33d9b1f20a223a6493c896da249b5
# Successfully built insightface
# Installing collected packages: protobuf, onnx, insightface
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
# Successfully installed insightface-0.7.3 onnx-1.14.0 protobuf-4.24.0
# Collecting onnxruntime>=1.15.0
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 17.2 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime>=1.15.0)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0) (23.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0) (4.24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0) (1.11.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.15.0)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.15.0) (1.3.0)
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.15.1
# Requirement already satisfied: opencv-python>=4.7.0.72 in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Collecting opencv-python>=4.7.0.72
#   Downloading opencv_python-4.8.0.76-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python>=4.7.0.72) (1.23.5)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.7.0.72
#     Uninstalling opencv-python-4.7.0.72:
#       Successfully uninstalled opencv-python-4.7.0.72
# Successfully installed opencv-python-4.8.0.76
#
# Error completing request
# Arguments: ('task(cf32mvnhrgdusho)', 0, 'Cat', '', [], None, None, None, None, None, None, None, 82, 0, 4, 0, 1, False, False, 1, 6, 7, 1.5, 0.75, -1.0, -1.0, 0, 0, 0, True, 0, 512, 512, 1, 0, 0, 32, 0, '', '', '', [], 0, <controlnet.py.UiControlNetUnit object at 0x7d65c57a0c40>, '<ul>\n<li><code>CFG Scale</code> should be 2 or lower.</li>\n</ul>\n', True, True, '', '', True, 50, True, 1, 0, False, 4, 0.5, 'Linear', 'None', '<p style="margin-bottom:0.75em">Recommended settings: Sampling Steps: 80-100, Sampler: Euler a, Denoising strength: 0.8</p>', 128, 8, ['left', 'right', 'up', 'down'], 1, 0.05, 128, 4, 0, ['left', 'right', 'up', 'down'], False, False, 'positive', 'comma', 0, False, False, '', '<p style="margin-bottom:0.75em">Will upscale the image by the selected scale factor; use width and height sliders to set tile size</p>', 64, 0, 2, 1, '', [], 0, '', [], 0, '', [], True, False, False, False, 0, None, False, 50) {}
# Traceback (most recent call last):
#   File "/content/lite_colab/modules/call_queue.py", line 57, in f
#     res = list(func(*args, **kwargs))
#   File "/content/lite_colab/modules/call_queue.py", line 37, in f
#     res = func(*args, **kwargs)
#   File "/content/lite_colab/modules/img2img.py", line 90, in img2img
#     image = init_img.convert("RGB")
# AttributeError: 'NoneType' object has no attribute 'convert'
#
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening 'outputs/img2img-images'
# Error completing request
# Arguments: ('task(vbg8wqcr3fucvpf)', 0, 'Cat', '', [], None, None, None, None, None, None, None, 82, 0, 4, 0, 1, False, False, 1, 6, 7, 1.5, 0.75, -1.0, -1.0, 0, 0, 0, True, 0, 512, 512, 1, 0, 0, 32, 0, '', '', '', [], 0, <controlnet.py.UiControlNetUnit object at 0x7d65c26aeef0>, '<ul>\n<li><code>CFG Scale</code> should be 2 or lower.</li>\n</ul>\n', True, True, '', '', True, 50, True, 1, 0, False, 4, 0.5, 'Linear', 'None', '<p style="margin-bottom:0.75em">Recommended settings: Sampling Steps: 80-100, Sampler: Euler a, Denoising strength: 0.8</p>', 128, 8, ['left', 'right', 'up', 'down'], 1, 0.05, 128, 4, 0, ['left', 'right', 'up', 'down'], False, False, 'positive', 'comma', 0, False, False, '', '<p style="margin-bottom:0.75em">Will upscale the image by the selected scale factor; use width and height sliders to set tile size</p>', 64, 0, 2, 1, '', [], 0, '', [], 0, '', [], True, False, False, False, 0, None, False, 50) {}
# Traceback (most recent call last):
#   File "/content/lite_colab/modules/call_queue.py", line 57, in f
#     res = list(func(*args, **kwargs))
#   File "/content/lite_colab/modules/call_queue.py", line 37, in f
#     res = func(*args, **kwargs)
#   File "/content/lite_colab/modules/img2img.py", line 90, in img2img
#     image = init_img.convert("RGB")
# AttributeError: 'NoneType' object has no attribute 'convert'

# %% [markdown]
# <form action="https://www.paypal.com/cgi-bin/webscr" method="post" target="_top">
#   <input type="hidden" name="cmd" value="_s-xclick" />
#   <input type="hidden" name="hosted_button_id" value="MDH8APKUVYW4L" />
#   <table>
#     <tr>
#       <td>
#         <input type="hidden" name="on0" value="Thank you for donation!:)"/>
#         Thank you for donation!:)
#       </td>
#     </tr>
#     <tr>
#       <td>
#         <input type="text" name="os0" maxLength="200" />
#       </td>
#     </tr>
#   </table>
#   <input type="hidden" name="currency_code" value="USD" />
#   <input type="image" src="https://www.paypalobjects.com/en_US/i/btn/btn_paynowCC_LG.gif" border="0" name="submit" title="PayPal - The safer, easier way to pay online!" alt="Buy Now" />
# </form>
